# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd '/content/drive/MyDrive/deep-orderbook-master/'
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/deep-orderbook-master

# %%
import os
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import gc
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
#print(os.getcwd())
paths = './coinbase_btc_usd/coinbase/btc_usd/l2_snapshots/100ms/'
#print(os.listdir(paths))
num_files = len([f for f in os.listdir(paths) if os.path.isfile(os.path.join(paths, f))])
print(f"Number of files in the folder: {num_files}")
# Out:
# Number of files in the folder: 216

# %%
count = 0
register = {}
day = {}
l2_snapshot = None  # Keep l2_snapshot as a PyTorch tensor on GPU

i = 0
for x in os.listdir(paths):
    path = paths + x
    temp = pd.read_parquet(path)
    # Load the DataFrame to GPU and keep it as a dictionary of tensors
    temp = {col: torch.tensor(temp[col].to_numpy(), device=device, dtype=torch.float32) for col in temp.columns}

    if count%24 == 0:
        day = temp  # Initialize day with temp when count is divisible by 24
    else:
        for col in temp.keys():
            if col in day:
                day[col] = torch.cat((day[col], temp[col]), dim=0)  # Concatenate tensors on GPU
            else:
                day[col] = temp[col]

    i += 1
    count +=1

    if count%24 == 0:
        flag = not register
        # Drop NaNs on GPU (replace NaNs with a placeholder and filter)
        for col in day.keys():
            mask = ~torch.isnan(day[col])  # Keep non-NaN values
            day[col] = day[col][mask]

        #print(day.shape)
        print({col: day[col].shape for col in day.keys()})  # Print shapes of tensors
        result = []

        # Perform calculations (mean, std) on GPU
        for cols, values in day.items():
            mean =values.mean().item()
            std = values.std().item()
            result.append([cols,[mean,std]])

        register[count/24] = result

        if not flag:
            for l in range(200): # Process the first 200 columns
                prev_stat = register[(count/24)-1]
                col_name = prev_stat[l][0]
                col_mean = prev_stat[l][1][0]
                col_std = prev_stat[l][1][1]
                # Normalize on GPU
                if col_name in day:
                    day[col_name] = (day[col_name] - col_mean) / col_std

            # Combine day into l2_snapshot
            if l2_snapshot is None:
                 # Ensure all tensors have at least two dimensions
                l2_snapshot = torch.cat([day[col].unsqueeze(1) if day[col].dim() == 1 else day[col] for col in day.keys()], dim=1)
            else:
                new_snapshot = torch.cat([day[col].unsqueeze(1) if day[col].dim() == 1 else day[col] for col in day.keys()], dim=1)
                l2_snapshot = torch.cat([l2_snapshot, new_snapshot], dim=0)

        # Delete the day data from GPU memory
        del day
        day = {}

    if i>240:
        break
# Out:
# {'b1': torch.Size([435489]), 'b2': torch.Size([435489]), 'b3': torch.Size([435489]), 'b4': torch.Size([435489]), 'b5': torch.Size([435489]), 'b6': torch.Size([435489]), 'b7': torch.Size([435489]), 'b8': torch.Size([435489]), 'b9': torch.Size([435489]), 'b10': torch.Size([435489]), 'b11': torch.Size([435489]), 'b12': torch.Size([435489]), 'b13': torch.Size([435489]), 'b14': torch.Size([435489]), 'b15': torch.Size([435489]), 'b16': torch.Size([435489]), 'b17': torch.Size([435489]), 'b18': torch.Size([435489]), 'b19': torch.Size([435489]), 'b20': torch.Size([435489]), 'b21': torch.Size([435489]), 'b22': torch.Size([435489]), 'b23': torch.Size([435489]), 'b24': torch.Size([435489]), 'b25': torch.Size([435489]), 'b26': torch.Size([435489]), 'b27': torch.Size([435489]), 'b28': torch.Size([435489]), 'b29': torch.Size([435489]), 'b30': torch.Size([435489]), 'b31': torch.Size([435489]), 'b32': torch.Size([435489]), 'b33': torch.Size([435489]), 'b34': torch.Size([435489]), 'b35': torch.Size([435489]), 'b36': torch.Size([435489]), 'b37': torch.Size([435489]), 'b38': torch.Size([435489]), 'b39': torch.Size([435489]), 'b40': torch.Size([435489]), 'b41': torch.Size([435489]), 'b42': torch.Size([435489]), 'b43': torch.Size([435489]), 'b44': torch.Size([435489]), 'b45': torch.Size([435489]), 'b46': torch.Size([435489]), 'b47': torch.Size([435489]), 'b48': torch.Size([435489]), 'b49': torch.Size([435489]), 'b50': torch.Size([435489]), 'a1': torch.Size([435489]), 'a2': torch.Size([435489]), 'a3': torch.Size([435489]), 'a4': torch.Size([435489]), 'a5': torch.Size([435489]), 'a6': torch.Size([435489]), 'a7': torch.Size([435489]), 'a8': torch.Size([435489]), 'a9': torch.Size([435489]), 'a10': torch.Size([435489]), 'a11': torch.Size([435489]), 'a12': torch.Size([435489]), 'a13': torch.Size([435489]), 'a14': torch.Size([435489]), 'a15': torch.Size([435489]), 'a16': torch.Size([435489]), 'a17': torch.Size([435489]), 'a18': torch.Size([435489]), 'a19': torch.Size([435489]), 'a20': torch.Size([435489]), 'a21': torch.Size([435489]), 'a22': torch.Size([435489]), 'a23': torch.Size([435489]), 'a24': torch.Size([435489]), 'a25': torch.Size([435489]), 'a26': torch.Size([435489]), 'a27': torch.Size([435489]), 'a28': torch.Size([435489]), 'a29': torch.Size([435489]), 'a30': torch.Size([435489]), 'a31': torch.Size([435489]), 'a32': torch.Size([435489]), 'a33': torch.Size([435489]), 'a34': torch.Size([435489]), 'a35': torch.Size([435489]), 'a36': torch.Size([435489]), 'a37': torch.Size([435489]), 'a38': torch.Size([435489]), 'a39': torch.Size([435489]), 'a40': torch.Size([435489]), 'a41': torch.Size([435489]), 'a42': torch.Size([435489]), 'a43': torch.Size([435489]), 'a44': torch.Size([435489]), 'a45': torch.Size([435489]), 'a46': torch.Size([435489]), 'a47': torch.Size([435489]), 'a48': torch.Size([435489]), 'a49': torch.Size([435489]), 'a50': torch.Size([435489]), 'bq1': torch.Size([435489]), 'bq2': torch.Size([435489]), 'bq3': torch.Size([435489]), 'bq4': torch.Size([435489]), 'bq5': torch.Size([435489]), 'bq6': torch.Size([435489]), 'bq7': torch.Size([435489]), 'bq8': torch.Size([435489]), 'bq9': torch.Size([435489]), 'bq10': torch.Size([435489]), 'bq11': torch.Size([435489]), 'bq12': torch.Size([435489]), 'bq13': torch.Size([435489]), 'bq14': torch.Size([435489]), 'bq15': torch.Size([435489]), 'bq16': torch.Size([435489]), 'bq17': torch.Size([435489]), 'bq18': torch.Size([435489]), 'bq19': torch.Size([435489]), 'bq20': torch.Size([435489]), 'bq21': torch.Size([435489]), 'bq22': torch.Size([435489]), 'bq23': torch.Size([435489]), 'bq24': torch.Size([435489]), 'bq25': torch.Size([435489]), 'bq26': torch.Size([435489]), 'bq27': torch.Size([435489]), 'bq28': torch.Size([435489]), 'bq29': torch.Size([435489]), 'bq30': torch.Size([435489]), 'bq31': torch.Size([435489]), 'bq32': torch.Size([435489]), 'bq33': torch.Size([435489]), 'bq34': torch.Size([435489]), 'bq35': torch.Size([435489]), 'bq36': torch.Size([435489]), 'bq37': torch.Size([435489]), 'bq38': torch.Si ...
# {'b1': torch.Size([498794]), 'b2': torch.Size([498794]), 'b3': torch.Size([498794]), 'b4': torch.Size([498794]), 'b5': torch.Size([498794]), 'b6': torch.Size([498794]), 'b7': torch.Size([498794]), 'b8': torch.Size([498794]), 'b9': torch.Size([498794]), 'b10': torch.Size([498794]), 'b11': torch.Size([498794]), 'b12': torch.Size([498794]), 'b13': torch.Size([498794]), 'b14': torch.Size([498794]), 'b15': torch.Size([498794]), 'b16': torch.Size([498794]), 'b17': torch.Size([498794]), 'b18': torch.Size([498794]), 'b19': torch.Size([498794]), 'b20': torch.Size([498794]), 'b21': torch.Size([498794]), 'b22': torch.Size([498794]), 'b23': torch.Size([498794]), 'b24': torch.Size([498794]), 'b25': torch.Size([498794]), 'b26': torch.Size([498794]), 'b27': torch.Size([498794]), 'b28': torch.Size([498794]), 'b29': torch.Size([498794]), 'b30': torch.Size([498794]), 'b31': torch.Size([498794]), 'b32': torch.Size([498794]), 'b33': torch.Size([498794]), 'b34': torch.Size([498794]), 'b35': torch.Size([498794]), 'b36': torch.Size([498794]), 'b37': torch.Size([498794]), 'b38': torch.Size([498794]), 'b39': torch.Size([498794]), 'b40': torch.Size([498794]), 'b41': torch.Size([498794]), 'b42': torch.Size([498794]), 'b43': torch.Size([498794]), 'b44': torch.Size([498794]), 'b45': torch.Size([498794]), 'b46': torch.Size([498794]), 'b47': torch.Size([498794]), 'b48': torch.Size([498794]), 'b49': torch.Size([498794]), 'b50': torch.Size([498794]), 'a1': torch.Size([498794]), 'a2': torch.Size([498794]), 'a3': torch.Size([498794]), 'a4': torch.Size([498794]), 'a5': torch.Size([498794]), 'a6': torch.Size([498794]), 'a7': torch.Size([498794]), 'a8': torch.Size([498794]), 'a9': torch.Size([498794]), 'a10': torch.Size([498794]), 'a11': torch.Size([498794]), 'a12': torch.Size([498794]), 'a13': torch.Size([498794]), 'a14': torch.Size([498794]), 'a15': torch.Size([498794]), 'a16': torch.Size([498794]), 'a17': torch.Size([498794]), 'a18': torch.Size([498794]), 'a19': torch.Size([498794]), 'a20': torch.Size([498794]), 'a21': torch.Size([498794]), 'a22': torch.Size([498794]), 'a23': torch.Size([498794]), 'a24': torch.Size([498794]), 'a25': torch.Size([498794]), 'a26': torch.Size([498794]), 'a27': torch.Size([498794]), 'a28': torch.Size([498794]), 'a29': torch.Size([498794]), 'a30': torch.Size([498794]), 'a31': torch.Size([498794]), 'a32': torch.Size([498794]), 'a33': torch.Size([498794]), 'a34': torch.Size([498794]), 'a35': torch.Size([498794]), 'a36': torch.Size([498794]), 'a37': torch.Size([498794]), 'a38': torch.Size([498794]), 'a39': torch.Size([498794]), 'a40': torch.Size([498794]), 'a41': torch.Size([498794]), 'a42': torch.Size([498794]), 'a43': torch.Size([498794]), 'a44': torch.Size([498794]), 'a45': torch.Size([498794]), 'a46': torch.Size([498794]), 'a47': torch.Size([498794]), 'a48': torch.Size([498794]), 'a49': torch.Size([498794]), 'a50': torch.Size([498794]), 'bq1': torch.Size([498794]), 'bq2': torch.Size([498794]), 'bq3': torch.Size([498794]), 'bq4': torch.Size([498794]), 'bq5': torch.Size([498794]), 'bq6': torch.Size([498794]), 'bq7': torch.Size([498794]), 'bq8': torch.Size([498794]), 'bq9': torch.Size([498794]), 'bq10': torch.Size([498794]), 'bq11': torch.Size([498794]), 'bq12': torch.Size([498794]), 'bq13': torch.Size([498794]), 'bq14': torch.Size([498794]), 'bq15': torch.Size([498794]), 'bq16': torch.Size([498794]), 'bq17': torch.Size([498794]), 'bq18': torch.Size([498794]), 'bq19': torch.Size([498794]), 'bq20': torch.Size([498794]), 'bq21': torch.Size([498794]), 'bq22': torch.Size([498794]), 'bq23': torch.Size([498794]), 'bq24': torch.Size([498794]), 'bq25': torch.Size([498794]), 'bq26': torch.Size([498794]), 'bq27': torch.Size([498794]), 'bq28': torch.Size([498794]), 'bq29': torch.Size([498794]), 'bq30': torch.Size([498794]), 'bq31': torch.Size([498794]), 'bq32': torch.Size([498794]), 'bq33': torch.Size([498794]), 'bq34': torch.Size([498794]), 'bq35': torch.Size([498794]), 'bq36': torch.Size([498794]), 'bq37': torch.Size([498794]), 'bq38': torch.Si ...
# {'b1': torch.Size([518048]), 'b2': torch.Size([518048]), 'b3': torch.Size([518048]), 'b4': torch.Size([518048]), 'b5': torch.Size([518048]), 'b6': torch.Size([518048]), 'b7': torch.Size([518048]), 'b8': torch.Size([518048]), 'b9': torch.Size([518048]), 'b10': torch.Size([518048]), 'b11': torch.Size([518048]), 'b12': torch.Size([518048]), 'b13': torch.Size([518048]), 'b14': torch.Size([518048]), 'b15': torch.Size([518048]), 'b16': torch.Size([518048]), 'b17': torch.Size([518048]), 'b18': torch.Size([518048]), 'b19': torch.Size([518048]), 'b20': torch.Size([518048]), 'b21': torch.Size([518048]), 'b22': torch.Size([518048]), 'b23': torch.Size([518048]), 'b24': torch.Size([518048]), 'b25': torch.Size([518048]), 'b26': torch.Size([518048]), 'b27': torch.Size([518048]), 'b28': torch.Size([518048]), 'b29': torch.Size([518048]), 'b30': torch.Size([518048]), 'b31': torch.Size([518048]), 'b32': torch.Size([518048]), 'b33': torch.Size([518048]), 'b34': torch.Size([518048]), 'b35': torch.Size([518048]), 'b36': torch.Size([518048]), 'b37': torch.Size([518048]), 'b38': torch.Size([518048]), 'b39': torch.Size([518048]), 'b40': torch.Size([518048]), 'b41': torch.Size([518048]), 'b42': torch.Size([518048]), 'b43': torch.Size([518048]), 'b44': torch.Size([518048]), 'b45': torch.Size([518048]), 'b46': torch.Size([518048]), 'b47': torch.Size([518048]), 'b48': torch.Size([518048]), 'b49': torch.Size([518048]), 'b50': torch.Size([518048]), 'a1': torch.Size([518048]), 'a2': torch.Size([518048]), 'a3': torch.Size([518048]), 'a4': torch.Size([518048]), 'a5': torch.Size([518048]), 'a6': torch.Size([518048]), 'a7': torch.Size([518048]), 'a8': torch.Size([518048]), 'a9': torch.Size([518048]), 'a10': torch.Size([518048]), 'a11': torch.Size([518048]), 'a12': torch.Size([518048]), 'a13': torch.Size([518048]), 'a14': torch.Size([518048]), 'a15': torch.Size([518048]), 'a16': torch.Size([518048]), 'a17': torch.Size([518048]), 'a18': torch.Size([518048]), 'a19': torch.Size([518048]), 'a20': torch.Size([518048]), 'a21': torch.Size([518048]), 'a22': torch.Size([518048]), 'a23': torch.Size([518048]), 'a24': torch.Size([518048]), 'a25': torch.Size([518048]), 'a26': torch.Size([518048]), 'a27': torch.Size([518048]), 'a28': torch.Size([518048]), 'a29': torch.Size([518048]), 'a30': torch.Size([518048]), 'a31': torch.Size([518048]), 'a32': torch.Size([518048]), 'a33': torch.Size([518048]), 'a34': torch.Size([518048]), 'a35': torch.Size([518048]), 'a36': torch.Size([518048]), 'a37': torch.Size([518048]), 'a38': torch.Size([518048]), 'a39': torch.Size([518048]), 'a40': torch.Size([518048]), 'a41': torch.Size([518048]), 'a42': torch.Size([518048]), 'a43': torch.Size([518048]), 'a44': torch.Size([518048]), 'a45': torch.Size([518048]), 'a46': torch.Size([518048]), 'a47': torch.Size([518048]), 'a48': torch.Size([518048]), 'a49': torch.Size([518048]), 'a50': torch.Size([518048]), 'bq1': torch.Size([518048]), 'bq2': torch.Size([518048]), 'bq3': torch.Size([518048]), 'bq4': torch.Size([518048]), 'bq5': torch.Size([518048]), 'bq6': torch.Size([518048]), 'bq7': torch.Size([518048]), 'bq8': torch.Size([518048]), 'bq9': torch.Size([518048]), 'bq10': torch.Size([518048]), 'bq11': torch.Size([518048]), 'bq12': torch.Size([518048]), 'bq13': torch.Size([518048]), 'bq14': torch.Size([518048]), 'bq15': torch.Size([518048]), 'bq16': torch.Size([518048]), 'bq17': torch.Size([518048]), 'bq18': torch.Size([518048]), 'bq19': torch.Size([518048]), 'bq20': torch.Size([518048]), 'bq21': torch.Size([518048]), 'bq22': torch.Size([518048]), 'bq23': torch.Size([518048]), 'bq24': torch.Size([518048]), 'bq25': torch.Size([518048]), 'bq26': torch.Size([518048]), 'bq27': torch.Size([518048]), 'bq28': torch.Size([518048]), 'bq29': torch.Size([518048]), 'bq30': torch.Size([518048]), 'bq31': torch.Size([518048]), 'bq32': torch.Size([518048]), 'bq33': torch.Size([518048]), 'bq34': torch.Size([518048]), 'bq35': torch.Size([518048]), 'bq36': torch.Size([518048]), 'bq37': torch.Size([518048]), 'bq38': torch.Si ...
# {'b1': torch.Size([491104]), 'b2': torch.Size([491104]), 'b3': torch.Size([491104]), 'b4': torch.Size([491104]), 'b5': torch.Size([491104]), 'b6': torch.Size([491104]), 'b7': torch.Size([491104]), 'b8': torch.Size([491104]), 'b9': torch.Size([491104]), 'b10': torch.Size([491104]), 'b11': torch.Size([491104]), 'b12': torch.Size([491104]), 'b13': torch.Size([491104]), 'b14': torch.Size([491104]), 'b15': torch.Size([491104]), 'b16': torch.Size([491104]), 'b17': torch.Size([491104]), 'b18': torch.Size([491104]), 'b19': torch.Size([491104]), 'b20': torch.Size([491104]), 'b21': torch.Size([491104]), 'b22': torch.Size([491104]), 'b23': torch.Size([491104]), 'b24': torch.Size([491104]), 'b25': torch.Size([491104]), 'b26': torch.Size([491104]), 'b27': torch.Size([491104]), 'b28': torch.Size([491104]), 'b29': torch.Size([491104]), 'b30': torch.Size([491104]), 'b31': torch.Size([491104]), 'b32': torch.Size([491104]), 'b33': torch.Size([491104]), 'b34': torch.Size([491104]), 'b35': torch.Size([491104]), 'b36': torch.Size([491104]), 'b37': torch.Size([491104]), 'b38': torch.Size([491104]), 'b39': torch.Size([491104]), 'b40': torch.Size([491104]), 'b41': torch.Size([491104]), 'b42': torch.Size([491104]), 'b43': torch.Size([491104]), 'b44': torch.Size([491104]), 'b45': torch.Size([491104]), 'b46': torch.Size([491104]), 'b47': torch.Size([491104]), 'b48': torch.Size([491104]), 'b49': torch.Size([491104]), 'b50': torch.Size([491104]), 'a1': torch.Size([491104]), 'a2': torch.Size([491104]), 'a3': torch.Size([491104]), 'a4': torch.Size([491104]), 'a5': torch.Size([491104]), 'a6': torch.Size([491104]), 'a7': torch.Size([491104]), 'a8': torch.Size([491104]), 'a9': torch.Size([491104]), 'a10': torch.Size([491104]), 'a11': torch.Size([491104]), 'a12': torch.Size([491104]), 'a13': torch.Size([491104]), 'a14': torch.Size([491104]), 'a15': torch.Size([491104]), 'a16': torch.Size([491104]), 'a17': torch.Size([491104]), 'a18': torch.Size([491104]), 'a19': torch.Size([491104]), 'a20': torch.Size([491104]), 'a21': torch.Size([491104]), 'a22': torch.Size([491104]), 'a23': torch.Size([491104]), 'a24': torch.Size([491104]), 'a25': torch.Size([491104]), 'a26': torch.Size([491104]), 'a27': torch.Size([491104]), 'a28': torch.Size([491104]), 'a29': torch.Size([491104]), 'a30': torch.Size([491104]), 'a31': torch.Size([491104]), 'a32': torch.Size([491104]), 'a33': torch.Size([491104]), 'a34': torch.Size([491104]), 'a35': torch.Size([491104]), 'a36': torch.Size([491104]), 'a37': torch.Size([491104]), 'a38': torch.Size([491104]), 'a39': torch.Size([491104]), 'a40': torch.Size([491104]), 'a41': torch.Size([491104]), 'a42': torch.Size([491104]), 'a43': torch.Size([491104]), 'a44': torch.Size([491104]), 'a45': torch.Size([491104]), 'a46': torch.Size([491104]), 'a47': torch.Size([491104]), 'a48': torch.Size([491104]), 'a49': torch.Size([491104]), 'a50': torch.Size([491104]), 'bq1': torch.Size([491104]), 'bq2': torch.Size([491104]), 'bq3': torch.Size([491104]), 'bq4': torch.Size([491104]), 'bq5': torch.Size([491104]), 'bq6': torch.Size([491104]), 'bq7': torch.Size([491104]), 'bq8': torch.Size([491104]), 'bq9': torch.Size([491104]), 'bq10': torch.Size([491104]), 'bq11': torch.Size([491104]), 'bq12': torch.Size([491104]), 'bq13': torch.Size([491104]), 'bq14': torch.Size([491104]), 'bq15': torch.Size([491104]), 'bq16': torch.Size([491104]), 'bq17': torch.Size([491104]), 'bq18': torch.Size([491104]), 'bq19': torch.Size([491104]), 'bq20': torch.Size([491104]), 'bq21': torch.Size([491104]), 'bq22': torch.Size([491104]), 'bq23': torch.Size([491104]), 'bq24': torch.Size([491104]), 'bq25': torch.Size([491104]), 'bq26': torch.Size([491104]), 'bq27': torch.Size([491104]), 'bq28': torch.Size([491104]), 'bq29': torch.Size([491104]), 'bq30': torch.Size([491104]), 'bq31': torch.Size([491104]), 'bq32': torch.Size([491104]), 'bq33': torch.Size([491104]), 'bq34': torch.Size([491104]), 'bq35': torch.Size([491104]), 'bq36': torch.Size([491104]), 'bq37': torch.Size([491104]), 'bq38': torch.Si ...
# {'b1': torch.Size([550746]), 'b2': torch.Size([550746]), 'b3': torch.Size([550746]), 'b4': torch.Size([550746]), 'b5': torch.Size([550746]), 'b6': torch.Size([550746]), 'b7': torch.Size([550746]), 'b8': torch.Size([550746]), 'b9': torch.Size([550746]), 'b10': torch.Size([550746]), 'b11': torch.Size([550746]), 'b12': torch.Size([550746]), 'b13': torch.Size([550746]), 'b14': torch.Size([550746]), 'b15': torch.Size([550746]), 'b16': torch.Size([550746]), 'b17': torch.Size([550746]), 'b18': torch.Size([550746]), 'b19': torch.Size([550746]), 'b20': torch.Size([550746]), 'b21': torch.Size([550746]), 'b22': torch.Size([550746]), 'b23': torch.Size([550746]), 'b24': torch.Size([550746]), 'b25': torch.Size([550746]), 'b26': torch.Size([550746]), 'b27': torch.Size([550746]), 'b28': torch.Size([550746]), 'b29': torch.Size([550746]), 'b30': torch.Size([550746]), 'b31': torch.Size([550746]), 'b32': torch.Size([550746]), 'b33': torch.Size([550746]), 'b34': torch.Size([550746]), 'b35': torch.Size([550746]), 'b36': torch.Size([550746]), 'b37': torch.Size([550746]), 'b38': torch.Size([550746]), 'b39': torch.Size([550746]), 'b40': torch.Size([550746]), 'b41': torch.Size([550746]), 'b42': torch.Size([550746]), 'b43': torch.Size([550746]), 'b44': torch.Size([550746]), 'b45': torch.Size([550746]), 'b46': torch.Size([550746]), 'b47': torch.Size([550746]), 'b48': torch.Size([550746]), 'b49': torch.Size([550746]), 'b50': torch.Size([550746]), 'a1': torch.Size([550746]), 'a2': torch.Size([550746]), 'a3': torch.Size([550746]), 'a4': torch.Size([550746]), 'a5': torch.Size([550746]), 'a6': torch.Size([550746]), 'a7': torch.Size([550746]), 'a8': torch.Size([550746]), 'a9': torch.Size([550746]), 'a10': torch.Size([550746]), 'a11': torch.Size([550746]), 'a12': torch.Size([550746]), 'a13': torch.Size([550746]), 'a14': torch.Size([550746]), 'a15': torch.Size([550746]), 'a16': torch.Size([550746]), 'a17': torch.Size([550746]), 'a18': torch.Size([550746]), 'a19': torch.Size([550746]), 'a20': torch.Size([550746]), 'a21': torch.Size([550746]), 'a22': torch.Size([550746]), 'a23': torch.Size([550746]), 'a24': torch.Size([550746]), 'a25': torch.Size([550746]), 'a26': torch.Size([550746]), 'a27': torch.Size([550746]), 'a28': torch.Size([550746]), 'a29': torch.Size([550746]), 'a30': torch.Size([550746]), 'a31': torch.Size([550746]), 'a32': torch.Size([550746]), 'a33': torch.Size([550746]), 'a34': torch.Size([550746]), 'a35': torch.Size([550746]), 'a36': torch.Size([550746]), 'a37': torch.Size([550746]), 'a38': torch.Size([550746]), 'a39': torch.Size([550746]), 'a40': torch.Size([550746]), 'a41': torch.Size([550746]), 'a42': torch.Size([550746]), 'a43': torch.Size([550746]), 'a44': torch.Size([550746]), 'a45': torch.Size([550746]), 'a46': torch.Size([550746]), 'a47': torch.Size([550746]), 'a48': torch.Size([550746]), 'a49': torch.Size([550746]), 'a50': torch.Size([550746]), 'bq1': torch.Size([550746]), 'bq2': torch.Size([550746]), 'bq3': torch.Size([550746]), 'bq4': torch.Size([550746]), 'bq5': torch.Size([550746]), 'bq6': torch.Size([550746]), 'bq7': torch.Size([550746]), 'bq8': torch.Size([550746]), 'bq9': torch.Size([550746]), 'bq10': torch.Size([550746]), 'bq11': torch.Size([550746]), 'bq12': torch.Size([550746]), 'bq13': torch.Size([550746]), 'bq14': torch.Size([550746]), 'bq15': torch.Size([550746]), 'bq16': torch.Size([550746]), 'bq17': torch.Size([550746]), 'bq18': torch.Size([550746]), 'bq19': torch.Size([550746]), 'bq20': torch.Size([550746]), 'bq21': torch.Size([550746]), 'bq22': torch.Size([550746]), 'bq23': torch.Size([550746]), 'bq24': torch.Size([550746]), 'bq25': torch.Size([550746]), 'bq26': torch.Size([550746]), 'bq27': torch.Size([550746]), 'bq28': torch.Size([550746]), 'bq29': torch.Size([550746]), 'bq30': torch.Size([550746]), 'bq31': torch.Size([550746]), 'bq32': torch.Size([550746]), 'bq33': torch.Size([550746]), 'bq34': torch.Size([550746]), 'bq35': torch.Size([550746]), 'bq36': torch.Size([550746]), 'bq37': torch.Size([550746]), 'bq38': torch.Si ...
# {'b1': torch.Size([616003]), 'b2': torch.Size([616003]), 'b3': torch.Size([616003]), 'b4': torch.Size([616003]), 'b5': torch.Size([616003]), 'b6': torch.Size([616003]), 'b7': torch.Size([616003]), 'b8': torch.Size([616003]), 'b9': torch.Size([616003]), 'b10': torch.Size([616003]), 'b11': torch.Size([616003]), 'b12': torch.Size([616003]), 'b13': torch.Size([616003]), 'b14': torch.Size([616003]), 'b15': torch.Size([616003]), 'b16': torch.Size([616003]), 'b17': torch.Size([616003]), 'b18': torch.Size([616003]), 'b19': torch.Size([616003]), 'b20': torch.Size([616003]), 'b21': torch.Size([616003]), 'b22': torch.Size([616003]), 'b23': torch.Size([616003]), 'b24': torch.Size([616003]), 'b25': torch.Size([616003]), 'b26': torch.Size([616003]), 'b27': torch.Size([616003]), 'b28': torch.Size([616003]), 'b29': torch.Size([616003]), 'b30': torch.Size([616003]), 'b31': torch.Size([616003]), 'b32': torch.Size([616003]), 'b33': torch.Size([616003]), 'b34': torch.Size([616003]), 'b35': torch.Size([616003]), 'b36': torch.Size([616003]), 'b37': torch.Size([616003]), 'b38': torch.Size([616003]), 'b39': torch.Size([616003]), 'b40': torch.Size([616003]), 'b41': torch.Size([616003]), 'b42': torch.Size([616003]), 'b43': torch.Size([616003]), 'b44': torch.Size([616003]), 'b45': torch.Size([616003]), 'b46': torch.Size([616003]), 'b47': torch.Size([616003]), 'b48': torch.Size([616003]), 'b49': torch.Size([616003]), 'b50': torch.Size([616003]), 'a1': torch.Size([616003]), 'a2': torch.Size([616003]), 'a3': torch.Size([616003]), 'a4': torch.Size([616003]), 'a5': torch.Size([616003]), 'a6': torch.Size([616003]), 'a7': torch.Size([616003]), 'a8': torch.Size([616003]), 'a9': torch.Size([616003]), 'a10': torch.Size([616003]), 'a11': torch.Size([616003]), 'a12': torch.Size([616003]), 'a13': torch.Size([616003]), 'a14': torch.Size([616003]), 'a15': torch.Size([616003]), 'a16': torch.Size([616003]), 'a17': torch.Size([616003]), 'a18': torch.Size([616003]), 'a19': torch.Size([616003]), 'a20': torch.Size([616003]), 'a21': torch.Size([616003]), 'a22': torch.Size([616003]), 'a23': torch.Size([616003]), 'a24': torch.Size([616003]), 'a25': torch.Size([616003]), 'a26': torch.Size([616003]), 'a27': torch.Size([616003]), 'a28': torch.Size([616003]), 'a29': torch.Size([616003]), 'a30': torch.Size([616003]), 'a31': torch.Size([616003]), 'a32': torch.Size([616003]), 'a33': torch.Size([616003]), 'a34': torch.Size([616003]), 'a35': torch.Size([616003]), 'a36': torch.Size([616003]), 'a37': torch.Size([616003]), 'a38': torch.Size([616003]), 'a39': torch.Size([616003]), 'a40': torch.Size([616003]), 'a41': torch.Size([616003]), 'a42': torch.Size([616003]), 'a43': torch.Size([616003]), 'a44': torch.Size([616003]), 'a45': torch.Size([616003]), 'a46': torch.Size([616003]), 'a47': torch.Size([616003]), 'a48': torch.Size([616003]), 'a49': torch.Size([616003]), 'a50': torch.Size([616003]), 'bq1': torch.Size([616003]), 'bq2': torch.Size([616003]), 'bq3': torch.Size([616003]), 'bq4': torch.Size([616003]), 'bq5': torch.Size([616003]), 'bq6': torch.Size([616003]), 'bq7': torch.Size([616003]), 'bq8': torch.Size([616003]), 'bq9': torch.Size([616003]), 'bq10': torch.Size([616003]), 'bq11': torch.Size([616003]), 'bq12': torch.Size([616003]), 'bq13': torch.Size([616003]), 'bq14': torch.Size([616003]), 'bq15': torch.Size([616003]), 'bq16': torch.Size([616003]), 'bq17': torch.Size([616003]), 'bq18': torch.Size([616003]), 'bq19': torch.Size([616003]), 'bq20': torch.Size([616003]), 'bq21': torch.Size([616003]), 'bq22': torch.Size([616003]), 'bq23': torch.Size([616003]), 'bq24': torch.Size([616003]), 'bq25': torch.Size([616003]), 'bq26': torch.Size([616003]), 'bq27': torch.Size([616003]), 'bq28': torch.Size([616003]), 'bq29': torch.Size([616003]), 'bq30': torch.Size([616003]), 'bq31': torch.Size([616003]), 'bq32': torch.Size([616003]), 'bq33': torch.Size([616003]), 'bq34': torch.Size([616003]), 'bq35': torch.Size([616003]), 'bq36': torch.Size([616003]), 'bq37': torch.Size([616003]), 'bq38': torch.Si ...
# {'b1': torch.Size([606227]), 'b2': torch.Size([606227]), 'b3': torch.Size([606227]), 'b4': torch.Size([606227]), 'b5': torch.Size([606227]), 'b6': torch.Size([606227]), 'b7': torch.Size([606227]), 'b8': torch.Size([606227]), 'b9': torch.Size([606227]), 'b10': torch.Size([606227]), 'b11': torch.Size([606227]), 'b12': torch.Size([606227]), 'b13': torch.Size([606227]), 'b14': torch.Size([606227]), 'b15': torch.Size([606227]), 'b16': torch.Size([606227]), 'b17': torch.Size([606227]), 'b18': torch.Size([606227]), 'b19': torch.Size([606227]), 'b20': torch.Size([606227]), 'b21': torch.Size([606227]), 'b22': torch.Size([606227]), 'b23': torch.Size([606227]), 'b24': torch.Size([606227]), 'b25': torch.Size([606227]), 'b26': torch.Size([606227]), 'b27': torch.Size([606227]), 'b28': torch.Size([606227]), 'b29': torch.Size([606227]), 'b30': torch.Size([606227]), 'b31': torch.Size([606227]), 'b32': torch.Size([606227]), 'b33': torch.Size([606227]), 'b34': torch.Size([606227]), 'b35': torch.Size([606227]), 'b36': torch.Size([606227]), 'b37': torch.Size([606227]), 'b38': torch.Size([606227]), 'b39': torch.Size([606227]), 'b40': torch.Size([606227]), 'b41': torch.Size([606227]), 'b42': torch.Size([606227]), 'b43': torch.Size([606227]), 'b44': torch.Size([606227]), 'b45': torch.Size([606227]), 'b46': torch.Size([606227]), 'b47': torch.Size([606227]), 'b48': torch.Size([606227]), 'b49': torch.Size([606227]), 'b50': torch.Size([606227]), 'a1': torch.Size([606227]), 'a2': torch.Size([606227]), 'a3': torch.Size([606227]), 'a4': torch.Size([606227]), 'a5': torch.Size([606227]), 'a6': torch.Size([606227]), 'a7': torch.Size([606227]), 'a8': torch.Size([606227]), 'a9': torch.Size([606227]), 'a10': torch.Size([606227]), 'a11': torch.Size([606227]), 'a12': torch.Size([606227]), 'a13': torch.Size([606227]), 'a14': torch.Size([606227]), 'a15': torch.Size([606227]), 'a16': torch.Size([606227]), 'a17': torch.Size([606227]), 'a18': torch.Size([606227]), 'a19': torch.Size([606227]), 'a20': torch.Size([606227]), 'a21': torch.Size([606227]), 'a22': torch.Size([606227]), 'a23': torch.Size([606227]), 'a24': torch.Size([606227]), 'a25': torch.Size([606227]), 'a26': torch.Size([606227]), 'a27': torch.Size([606227]), 'a28': torch.Size([606227]), 'a29': torch.Size([606227]), 'a30': torch.Size([606227]), 'a31': torch.Size([606227]), 'a32': torch.Size([606227]), 'a33': torch.Size([606227]), 'a34': torch.Size([606227]), 'a35': torch.Size([606227]), 'a36': torch.Size([606227]), 'a37': torch.Size([606227]), 'a38': torch.Size([606227]), 'a39': torch.Size([606227]), 'a40': torch.Size([606227]), 'a41': torch.Size([606227]), 'a42': torch.Size([606227]), 'a43': torch.Size([606227]), 'a44': torch.Size([606227]), 'a45': torch.Size([606227]), 'a46': torch.Size([606227]), 'a47': torch.Size([606227]), 'a48': torch.Size([606227]), 'a49': torch.Size([606227]), 'a50': torch.Size([606227]), 'bq1': torch.Size([606227]), 'bq2': torch.Size([606227]), 'bq3': torch.Size([606227]), 'bq4': torch.Size([606227]), 'bq5': torch.Size([606227]), 'bq6': torch.Size([606227]), 'bq7': torch.Size([606227]), 'bq8': torch.Size([606227]), 'bq9': torch.Size([606227]), 'bq10': torch.Size([606227]), 'bq11': torch.Size([606227]), 'bq12': torch.Size([606227]), 'bq13': torch.Size([606227]), 'bq14': torch.Size([606227]), 'bq15': torch.Size([606227]), 'bq16': torch.Size([606227]), 'bq17': torch.Size([606227]), 'bq18': torch.Size([606227]), 'bq19': torch.Size([606227]), 'bq20': torch.Size([606227]), 'bq21': torch.Size([606227]), 'bq22': torch.Size([606227]), 'bq23': torch.Size([606227]), 'bq24': torch.Size([606227]), 'bq25': torch.Size([606227]), 'bq26': torch.Size([606227]), 'bq27': torch.Size([606227]), 'bq28': torch.Size([606227]), 'bq29': torch.Size([606227]), 'bq30': torch.Size([606227]), 'bq31': torch.Size([606227]), 'bq32': torch.Size([606227]), 'bq33': torch.Size([606227]), 'bq34': torch.Size([606227]), 'bq35': torch.Size([606227]), 'bq36': torch.Size([606227]), 'bq37': torch.Size([606227]), 'bq38': torch.Si ...
# {'b1': torch.Size([553133]), 'b2': torch.Size([553133]), 'b3': torch.Size([553133]), 'b4': torch.Size([553133]), 'b5': torch.Size([553133]), 'b6': torch.Size([553133]), 'b7': torch.Size([553133]), 'b8': torch.Size([553133]), 'b9': torch.Size([553133]), 'b10': torch.Size([553133]), 'b11': torch.Size([553133]), 'b12': torch.Size([553133]), 'b13': torch.Size([553133]), 'b14': torch.Size([553133]), 'b15': torch.Size([553133]), 'b16': torch.Size([553133]), 'b17': torch.Size([553133]), 'b18': torch.Size([553133]), 'b19': torch.Size([553133]), 'b20': torch.Size([553133]), 'b21': torch.Size([553133]), 'b22': torch.Size([553133]), 'b23': torch.Size([553133]), 'b24': torch.Size([553133]), 'b25': torch.Size([553133]), 'b26': torch.Size([553133]), 'b27': torch.Size([553133]), 'b28': torch.Size([553133]), 'b29': torch.Size([553133]), 'b30': torch.Size([553133]), 'b31': torch.Size([553133]), 'b32': torch.Size([553133]), 'b33': torch.Size([553133]), 'b34': torch.Size([553133]), 'b35': torch.Size([553133]), 'b36': torch.Size([553133]), 'b37': torch.Size([553133]), 'b38': torch.Size([553133]), 'b39': torch.Size([553133]), 'b40': torch.Size([553133]), 'b41': torch.Size([553133]), 'b42': torch.Size([553133]), 'b43': torch.Size([553133]), 'b44': torch.Size([553133]), 'b45': torch.Size([553133]), 'b46': torch.Size([553133]), 'b47': torch.Size([553133]), 'b48': torch.Size([553133]), 'b49': torch.Size([553133]), 'b50': torch.Size([553133]), 'a1': torch.Size([553133]), 'a2': torch.Size([553133]), 'a3': torch.Size([553133]), 'a4': torch.Size([553133]), 'a5': torch.Size([553133]), 'a6': torch.Size([553133]), 'a7': torch.Size([553133]), 'a8': torch.Size([553133]), 'a9': torch.Size([553133]), 'a10': torch.Size([553133]), 'a11': torch.Size([553133]), 'a12': torch.Size([553133]), 'a13': torch.Size([553133]), 'a14': torch.Size([553133]), 'a15': torch.Size([553133]), 'a16': torch.Size([553133]), 'a17': torch.Size([553133]), 'a18': torch.Size([553133]), 'a19': torch.Size([553133]), 'a20': torch.Size([553133]), 'a21': torch.Size([553133]), 'a22': torch.Size([553133]), 'a23': torch.Size([553133]), 'a24': torch.Size([553133]), 'a25': torch.Size([553133]), 'a26': torch.Size([553133]), 'a27': torch.Size([553133]), 'a28': torch.Size([553133]), 'a29': torch.Size([553133]), 'a30': torch.Size([553133]), 'a31': torch.Size([553133]), 'a32': torch.Size([553133]), 'a33': torch.Size([553133]), 'a34': torch.Size([553133]), 'a35': torch.Size([553133]), 'a36': torch.Size([553133]), 'a37': torch.Size([553133]), 'a38': torch.Size([553133]), 'a39': torch.Size([553133]), 'a40': torch.Size([553133]), 'a41': torch.Size([553133]), 'a42': torch.Size([553133]), 'a43': torch.Size([553133]), 'a44': torch.Size([553133]), 'a45': torch.Size([553133]), 'a46': torch.Size([553133]), 'a47': torch.Size([553133]), 'a48': torch.Size([553133]), 'a49': torch.Size([553133]), 'a50': torch.Size([553133]), 'bq1': torch.Size([553133]), 'bq2': torch.Size([553133]), 'bq3': torch.Size([553133]), 'bq4': torch.Size([553133]), 'bq5': torch.Size([553133]), 'bq6': torch.Size([553133]), 'bq7': torch.Size([553133]), 'bq8': torch.Size([553133]), 'bq9': torch.Size([553133]), 'bq10': torch.Size([553133]), 'bq11': torch.Size([553133]), 'bq12': torch.Size([553133]), 'bq13': torch.Size([553133]), 'bq14': torch.Size([553133]), 'bq15': torch.Size([553133]), 'bq16': torch.Size([553133]), 'bq17': torch.Size([553133]), 'bq18': torch.Size([553133]), 'bq19': torch.Size([553133]), 'bq20': torch.Size([553133]), 'bq21': torch.Size([553133]), 'bq22': torch.Size([553133]), 'bq23': torch.Size([553133]), 'bq24': torch.Size([553133]), 'bq25': torch.Size([553133]), 'bq26': torch.Size([553133]), 'bq27': torch.Size([553133]), 'bq28': torch.Size([553133]), 'bq29': torch.Size([553133]), 'bq30': torch.Size([553133]), 'bq31': torch.Size([553133]), 'bq32': torch.Size([553133]), 'bq33': torch.Size([553133]), 'bq34': torch.Size([553133]), 'bq35': torch.Size([553133]), 'bq36': torch.Size([553133]), 'bq37': torch.Size([553133]), 'bq38': torch.Si ...
# {'b1': torch.Size([569603]), 'b2': torch.Size([569603]), 'b3': torch.Size([569603]), 'b4': torch.Size([569603]), 'b5': torch.Size([569603]), 'b6': torch.Size([569603]), 'b7': torch.Size([569603]), 'b8': torch.Size([569603]), 'b9': torch.Size([569603]), 'b10': torch.Size([569603]), 'b11': torch.Size([569603]), 'b12': torch.Size([569603]), 'b13': torch.Size([569603]), 'b14': torch.Size([569603]), 'b15': torch.Size([569603]), 'b16': torch.Size([569603]), 'b17': torch.Size([569603]), 'b18': torch.Size([569603]), 'b19': torch.Size([569603]), 'b20': torch.Size([569603]), 'b21': torch.Size([569603]), 'b22': torch.Size([569603]), 'b23': torch.Size([569603]), 'b24': torch.Size([569603]), 'b25': torch.Size([569603]), 'b26': torch.Size([569603]), 'b27': torch.Size([569603]), 'b28': torch.Size([569603]), 'b29': torch.Size([569603]), 'b30': torch.Size([569603]), 'b31': torch.Size([569603]), 'b32': torch.Size([569603]), 'b33': torch.Size([569603]), 'b34': torch.Size([569603]), 'b35': torch.Size([569603]), 'b36': torch.Size([569603]), 'b37': torch.Size([569603]), 'b38': torch.Size([569603]), 'b39': torch.Size([569603]), 'b40': torch.Size([569603]), 'b41': torch.Size([569603]), 'b42': torch.Size([569603]), 'b43': torch.Size([569603]), 'b44': torch.Size([569603]), 'b45': torch.Size([569603]), 'b46': torch.Size([569603]), 'b47': torch.Size([569603]), 'b48': torch.Size([569603]), 'b49': torch.Size([569603]), 'b50': torch.Size([569603]), 'a1': torch.Size([569603]), 'a2': torch.Size([569603]), 'a3': torch.Size([569603]), 'a4': torch.Size([569603]), 'a5': torch.Size([569603]), 'a6': torch.Size([569603]), 'a7': torch.Size([569603]), 'a8': torch.Size([569603]), 'a9': torch.Size([569603]), 'a10': torch.Size([569603]), 'a11': torch.Size([569603]), 'a12': torch.Size([569603]), 'a13': torch.Size([569603]), 'a14': torch.Size([569603]), 'a15': torch.Size([569603]), 'a16': torch.Size([569603]), 'a17': torch.Size([569603]), 'a18': torch.Size([569603]), 'a19': torch.Size([569603]), 'a20': torch.Size([569603]), 'a21': torch.Size([569603]), 'a22': torch.Size([569603]), 'a23': torch.Size([569603]), 'a24': torch.Size([569603]), 'a25': torch.Size([569603]), 'a26': torch.Size([569603]), 'a27': torch.Size([569603]), 'a28': torch.Size([569603]), 'a29': torch.Size([569603]), 'a30': torch.Size([569603]), 'a31': torch.Size([569603]), 'a32': torch.Size([569603]), 'a33': torch.Size([569603]), 'a34': torch.Size([569603]), 'a35': torch.Size([569603]), 'a36': torch.Size([569603]), 'a37': torch.Size([569603]), 'a38': torch.Size([569603]), 'a39': torch.Size([569603]), 'a40': torch.Size([569603]), 'a41': torch.Size([569603]), 'a42': torch.Size([569603]), 'a43': torch.Size([569603]), 'a44': torch.Size([569603]), 'a45': torch.Size([569603]), 'a46': torch.Size([569603]), 'a47': torch.Size([569603]), 'a48': torch.Size([569603]), 'a49': torch.Size([569603]), 'a50': torch.Size([569603]), 'bq1': torch.Size([569603]), 'bq2': torch.Size([569603]), 'bq3': torch.Size([569603]), 'bq4': torch.Size([569603]), 'bq5': torch.Size([569603]), 'bq6': torch.Size([569603]), 'bq7': torch.Size([569603]), 'bq8': torch.Size([569603]), 'bq9': torch.Size([569603]), 'bq10': torch.Size([569603]), 'bq11': torch.Size([569603]), 'bq12': torch.Size([569603]), 'bq13': torch.Size([569603]), 'bq14': torch.Size([569603]), 'bq15': torch.Size([569603]), 'bq16': torch.Size([569603]), 'bq17': torch.Size([569603]), 'bq18': torch.Size([569603]), 'bq19': torch.Size([569603]), 'bq20': torch.Size([569603]), 'bq21': torch.Size([569603]), 'bq22': torch.Size([569603]), 'bq23': torch.Size([569603]), 'bq24': torch.Size([569603]), 'bq25': torch.Size([569603]), 'bq26': torch.Size([569603]), 'bq27': torch.Size([569603]), 'bq28': torch.Size([569603]), 'bq29': torch.Size([569603]), 'bq30': torch.Size([569603]), 'bq31': torch.Size([569603]), 'bq32': torch.Size([569603]), 'bq33': torch.Size([569603]), 'bq34': torch.Size([569603]), 'bq35': torch.Size([569603]), 'bq36': torch.Size([569603]), 'bq37': torch.Size([569603]), 'bq38': torch.Si ...

# %%
# Define the column names and their indices in the tensor
column_names = ['b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8', 'b9', 'b10',
                'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9', 'a10',
                'bq1', 'bq2', 'bq3', 'bq4', 'bq5', 'bq6', 'bq7', 'bq8', 'bq9', 'bq10',
                'aq1', 'aq2', 'aq3', 'aq4', 'aq5', 'aq6', 'aq7', 'aq8', 'aq9', 'aq10']
# Assume these column names map to specific indices in the tensor
# Update this list with the corresponding column indices (0-based indexing)
column_indices = list(range(len(column_names)))

# Use indexing to select the desired columns from the tensor
l2_snapshot_ = l2_snapshot[:, column_indices]  # Select columns along the second dimension (dim=1)

# Verify the resulting tensor
print(f"Shape of l2_snapshot_: {l2_snapshot_.shape}")
# Out:
# Shape of l2_snapshot_: torch.Size([4403658, 40])

# %%
def generate_features_labels(df, ask, bid, k=20, alpha = 10e-5):
    # Move required columns to GPU
    #print(df[ask].dtype)
    # Extract ask and bid columns using indices, as l2_snapshot is a tensor
    ask_tensor = df[:, ask]  # Use numerical indexing for the ask column
    bid_tensor = df[:, bid]  # Use numerical indexing for the bid column

    # Compute mid_price and initialize target on GPU
    mid_price = (ask_tensor + bid_tensor) / 2
    target = torch.ones(mid_price.shape[0], device="cuda", dtype=torch.int32)

    shape = mid_price.shape[0]

    # Precompute initial means for m_b and m_a
    m_b = mid_price[:k].mean()
    m_a = mid_price[k+1:2*k+1].mean()
    val = mid_price[0]
    valB = mid_price[k+1]

    # Start the target calculation
    for i in tqdm(range(k, shape - k)):
        if i != k:
            # Update m_b and m_a incrementally
            curr_val = mid_price[i - 1]
            curr_valB = mid_price[i + k]
            m_b = (m_b * k + curr_val - val) / k
            m_a = (m_a * k + curr_valB - valB) / k
            val = mid_price[i - k]
            valB = mid_price[i + 1]

        # Update target using GPU-based operations
        if (m_b > m_a * (1 + alpha)):
            target[i] = 2
        if (m_b < m_a * (1 - alpha)):
            target[i] = 0

    # Slice the target and prepare features
    target = target[k:shape - k]  # Keep the relevant range of target
    features = df[k:shape - k, :].clone().detach().to(device="cuda", dtype=torch.float32)
    return features, target

# %%
print(type(l2_snapshot))
print(l2_snapshot.shape)
print(l2_snapshot[:, 1].dtype)
# Out:
# <class 'torch.Tensor'>
# torch.Size([4403658, 200])
# torch.float32

# %% [markdown]
# Bypass the following 2 cells since all data have been treated and save in "X_data.csv" and "y_data.csv"

# %%
# GridSearch
min_ = float('inf')
minI = 0

# Iterate over logarithmic values using PyTorch tensors
for i in torch.logspace(0, -8, steps=10, device="cuda"):  # Perform logspace directly on the GPU
    # Generate features and labels on the GPU
    X, y = generate_features_labels(l2_snapshot, ask=1, bid=1, alpha=i.item())

    # Convert labels to GPU tensor and calculate class counts
    y_ = y.clone().detach().to(device="cuda")
    temp = torch.bincount(y_)  # Equivalent to value_counts, works for categorical data

    # Handle cases where some categories may be missing
    if temp.size(0) < 3:  # Ensure all categories (0, 1, 2) are represented
        temp = torch.cat([temp, torch.zeros(3 - temp.size(0), device="cuda")])

    a, b, c = temp[0].item(), temp[1].item(), temp[2].item()  # Convert counts back to Python integers
    sum_ = a + b + c

    # Calculate l2 using GPU tensors
    l2 = ((1 / 3 - (a / sum_)) * 100) ** 2 + ((1 / 3  -(b / sum_)) * 100) ** 2 + ((1 / 3-(c / sum_)) * 100) ** 2

    # Update minimum l2 and corresponding alpha value
    if l2 < min_:
        min_ = l2
        minI = i.item()  # Use the alpha value

    # Clear GPU memory for variables not needed anymore
    del X, y, temp

print(f"Optimal alpha: {minI}, Minimum l2: {min_}")
# Out:
# 100%|██████████| 4403618/4403618 [13:13<00:00, 5550.97it/s]
# 100%|██████████| 4403618/4403618 [13:09<00:00, 5580.10it/s]
# 100%|██████████| 4403618/4403618 [13:08<00:00, 5585.79it/s]
# 100%|██████████| 4403618/4403618 [12:58<00:00, 5655.29it/s]
# 100%|██████████| 4403618/4403618 [12:57<00:00, 5664.98it/s]
# 100%|██████████| 4403618/4403618 [12:52<00:00, 5701.27it/s]
# 100%|██████████| 4403618/4403618 [12:56<00:00, 5670.71it/s]
# 100%|██████████| 4403618/4403618 [13:02<00:00, 5629.96it/s]
# 100%|██████████| 4403618/4403618 [12:56<00:00, 5670.90it/s]
# 100%|██████████| 4403618/4403618 [12:20<00:00, 5948.65it/s]
# Optimal alpha: 9.99999993922529e-09, Minimum l2: 12.552750812533187

# %%
minI = 9.99999993922529e-09
min_ = 12.552750812533187

X, y = generate_features_labels(l2_snapshot_, ask=1, bid=1, alpha=minI)
# Convert X and y into DataFrames
X_df = pd.DataFrame(X)
y_df = pd.DataFrame(y, columns=["label"])  # Naming the label column
# Write to CSV files
X_df.to_csv("X_data.csv", index=False)
y_df.to_csv("y_data.csv", index=False)

print("Data successfully written to CSV files.")
# Out:
# 100%|██████████| 4403618/4403618 [12:18<00:00, 5959.49it/s]

# %%
import pandas as pd
import torch

# Read CSV files into DataFrames
X_df = pd.read_csv("X_data.csv")
y_df = pd.read_csv("y_data.csv")

# Convert DataFrames to PyTorch tensors
X = torch.tensor(X_df.values, dtype=torch.float32)  # Ensure correct dtype
y = torch.tensor(y_df["label"].values, dtype=torch.long)  # Labels should be integers

del X_df, y_df
print("Shapes:", X.shape, y.shape)
# Out:
# Shapes: torch.Size([4403618, 40]) torch.Size([4403618])

# %%
#y = y.to(dtype=torch.int)
# Move tensor to CPU and convert to NumPy
y_cpu = y.cpu().numpy()
sns.countplot(x = y_cpu)
# Out:
# <Axes: ylabel='count'>

# %%
# Move tensor to CPU and compute class counts
#y_cpu = y.cpu()  # Transfer tensor to CPU
counts = torch.bincount(y_cpu)  # Compute counts for each class

# Plot counts using Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(range(len(counts)), counts.numpy(), color='skyblue')  # Create bar plot
plt.xticks(range(len(counts)), labels=[f'Class {i}' for i in range(len(counts))])  # Label classes
plt.title("Class Distribution")
plt.xlabel("Classes")
plt.ylabel("Frequency")
plt.show()

# %%
T = 100
D = 40
#trainPart = 3176046

percent = 0.4 #0.2 #0.1  # RAM restriction, use 10% of data
N = round(percent * len(X)) - T # RAM restriction, use 10% of data
trainPart = round(0.8 * N)
print("N=", N, " trainPart=", trainPart)
# Out:
# N= 1761347  trainPart= 1409078

# %%
#N = len(X) - T
#trainPart = 317604 #3176046 # RAM restriction, use 10% of data

# %%
X_train = torch.zeros((trainPart, T, D), dtype=torch.float32)
y_train = torch.zeros(trainPart, dtype=torch.long)

#Preparing the time series data using timestep of 100 and no of features = 200
for t in range(trainPart):
    X_train[t, :, :] = X[t:t+T].to(dtype=torch.float32)
    y_train[t] = y[t+T].to(dtype=torch.long)

print('X_train - Before: {} GB'.format(X_train.nbytes/1024**3), X_train.dtype)
print(X.shape)
print('y_train - Before: {} GB'.format(y_train.nbytes/1024**3), y_train.dtype)
print(y.shape)
# Out:
# X_train - Before: 20.996898412704468 GB torch.float32
# torch.Size([4403618, 40])
# y_train - Before: 0.010498449206352234 GB torch.int64
# torch.Size([4403618])

# %%
X_test = torch.zeros((N - trainPart, T, D), dtype=torch.float32)
y_test = torch.zeros(N - trainPart, dtype=torch.long)

#Preparing the time series data using timestep of 100 and no of features = 40
for k in range(N - trainPart):
    t = k + trainPart
    X_test[k, :, :] = X[t:t+T]
    y_test[k] = y[t+T]

print('X_test - Before: {} GB'.format(X_test.nbytes/1024**3), X_test.dtype)
print('y_test - Before: {} GB'.format(y_test.nbytes/1024**3), y_test.dtype)
# Out:
# X_test - Before: 5.24921715259552 GB torch.float32
# y_test - Before: 0.00262460857629776 GB torch.int64

# %%
# prompt: write X_train, y_train, X_test, y_test into csv files

import numpy as np
import pandas as pd

# Convert tensors to numpy arrays before saving to CSV
X_train_np = X_train.numpy()
y_train_np = y_train.numpy()
X_test_np = X_test.numpy()
y_test_np = y_test.numpy()

# Create pandas DataFrames
X_train_df = pd.DataFrame(X_train_np.reshape(X_train_np.shape[0], -1)) # Reshape for CSV compatibility
y_train_df = pd.DataFrame(y_train_np, columns=['label'])
X_test_df = pd.DataFrame(X_test_np.reshape(X_test_np.shape[0], -1)) # Reshape for CSV compatibility
y_test_df = pd.DataFrame(y_test_np, columns=['label'])

# Save DataFrames to CSV files
X_train_df.to_csv('X_train.csv', index=False)
y_train_df.to_csv('y_train.csv', index=False)
X_test_df.to_csv('X_test.csv', index=False)
y_test_df.to_csv('y_test.csv', index=False)

print("Data successfully written to CSV files.")
# Out:
# Data successfully written to CSV files.

# %%
# input the saved data
import pandas as pd
import torch

# Read CSV files into DataFrames
X_df = pd.read_csv("X_train.csv")
y_df = pd.read_csv("y_train.csv")

# Convert DataFrames to PyTorch tensors
X_train = torch.tensor(X_df.values, dtype=torch.float32)  # Ensure correct dtype
X_train = X_train.view(trainPart, T, D)
y_train = torch.tensor(y_df["label"].values, dtype=torch.long)  # Labels should be integers

# Read CSV files into DataFrames
X_df = pd.read_csv("X_test.csv")
y_df = pd.read_csv("y_test.csv")

# Convert DataFrames to PyTorch tensors
X_test = torch.tensor(X_df.values, dtype=torch.float32)  # Ensure correct dtype
X_test = X_test.view(N - trainPart, T, D)
y_test = torch.tensor(y_df["label"].values, dtype=torch.long)  # Labels should be integers

del X_df, y_df
print("Shapes:", X_train.shape, y_train.shape)
print("Shapes:", X_test.shape, y_test.shape)

# %%
from torch.utils.data import TensorDataset, DataLoader
# Create a TensorDataset
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
del X_train, y_train #, X_test, y_test

# %%
pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNN_RNN_Classifier(nn.Module):
    '''
    Keras model:
    Conv2D → Reshape → Conv1D → MaxPool1D → Conv1D → MaxPool1D → BiLSTM → Dense → Dense → Output
    Input: (batch_size, 100, 40, 1)
    '''

    def __init__(self, input_shape, T, D):
        super(CNN_RNN_Classifier, self).__init__()
        # First Conv2D layer, input (B, 1, 100, 40) -> output (B, 16, 97, 1)
        self.conv2d = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=(4, D))
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.01)
        # Reshape layer (to reshape for Conv1D)
        self.T = T  # Store T for dynamic reshaping
        # First Conv1D layer
        self.conv1d_1 = nn.Conv1d(in_channels=16, out_channels=16, kernel_size=4)
        # Batch Normalization
        self.bn1 = nn.BatchNorm1d(16, momentum=0.1)
        # MaxPooling1D
        self.maxpool1 = nn.MaxPool1d(kernel_size=2)
        # Second Conv1D layer
        self.conv1d_2 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3)
        # Batch Normalization
        self.bn2 = nn.BatchNorm1d(32, momentum=0.1)
        # MaxPooling1D
        self.maxpool2 = nn.MaxPool1d(kernel_size=2)
        # Bidirectional LSTM
        self.lstm = nn.LSTM(input_size=22, hidden_size=64, bidirectional=True, batch_first=True)
        # Dense layers
        self.fc1 = nn.Linear(64 * 2, 32)  # *2 because it's bidirectional
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 3)  # 3 output classes for softmax

    def forward(self, x):
        # Conv2D
        x = self.conv2d(x)
        x = self.leaky_relu(x)
        # Reshape from Conv2D output to match Conv1D input
        x = x.view(x.shape[0], 16, -1)
        # First Conv1D
        x = self.conv1d_1(x)
        # Batch Normalization + MaxPooling
        x = self.bn1(x)
        x = self.leaky_relu(x)
        # Batch Normalization + MaxPooling
        #x = self.bn1(x)
        x = self.maxpool1(x)
        # Second Conv1D
        x = self.conv1d_2(x)
        x = self.leaky_relu(x)
        # Batch Normalization + MaxPooling
        x = self.bn2(x)
        x = self.maxpool2(x)
        # Check the shape before LSTM
        #print("Shape before LSTM:", x.shape) # Print the shape before entering LSTM
        # Bidirectional LSTM
        x, _ = self.lstm(x)
        x = x[:, -1, :]  # Last time step
        # Dense layers
        x = self.fc1(x)
        x = self.leaky_relu(x)
        x = self.fc2(x)
        x = self.leaky_relu(x)
        x = self.fc3(x)
        # Softmax output
        #x = F.softmax(x, dim=-1)
        return x

# %%
from torchinfo import summary
input_size = (32, 1, 100, 40)  # (batch_size, channels, height, width)
summary(CNN_RNN_Classifier(input_shape=(32, T, D), T=100, D=40), input_size=input_size)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNN_RNN_Classifier                       [32, 3]                   --
# ├─Conv2d: 1-1                            [32, 16, 97, 1]           2,576
# ├─LeakyReLU: 1-2                         [32, 16, 97, 1]           --
# ├─Conv1d: 1-3                            [32, 16, 94]              1,040
# ├─BatchNorm1d: 1-4                       [32, 16, 94]              32
# ├─LeakyReLU: 1-5                         [32, 16, 94]              --
# ├─MaxPool1d: 1-6                         [32, 16, 47]              --
# ├─Conv1d: 1-7                            [32, 32, 45]              1,568
# ├─LeakyReLU: 1-8                         [32, 32, 45]              --
# ├─BatchNorm1d: 1-9                       [32, 32, 45]              64
# ├─MaxPool1d: 1-10                        [32, 32, 22]              --
# ├─LSTM: 1-11                             [32, 32, 128]             45,056
# ├─Linear: 1-12                           [32, 32]                  4,128
# ├─LeakyReLU: 1-13                        [32, 32]                  --
# ├─Linear: 1-14                           [32, 32]                  1,056
# ├─LeakyReLU: 1-15                        [32, 32]                  --
# ├─Linear: 1-16                           [32, 3]                   99
# ==========================================================================================
# Total params: 55,619
# Trainable params: 55,619
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 59.69
# ==========================================================================================
# Input size (MB): 0.51
# Forward/backward pass size (MB): 2.97
# Params size (MB): 0.22
# Estimated Total Size (MB): 3.70
# ==========================================================================================

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import math
from torch.amp import autocast

# Hyperparameters
epochs = 40 #10
batch_size = 32 #128 #32
learning_rate = 0.001 #0.00001 0.0001 #0.001

# Create TensorDataset
#train_dataset = TensorDataset(X_train, y_train)
#test_dataset = TensorDataset(X_test, y_test)
# Create DataLoader for batching
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)

# define model
model = CNN_RNN_Classifier(input_shape=(batch_size, T, D), T=T, D=D).to(device)  # Move model to GPU if available
# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)  # Use Adam optimizer
# Define the loss function
criterion = nn.CrossEntropyLoss()

# Define accuracy calculation (PyTorch doesn't include it natively)
def calculate_accuracy(y_pred, y_true):
    y_pred_classes = torch.argmax(y_pred, dim=1)  # Get class predictions
    y_true = y_true.to(y_pred_classes.device)
    correct = (y_pred_classes == y_true).sum().item()
    accuracy = correct / y_true.size(0)
    return accuracy
#
#
##### Training Loop #####
Train_Loss = np.array(epochs)
Train_Accuracy = np.array(epochs)
Test_Loss = np.array(epochs)
Test_Accuracy =np.array(epochs)
#
for epoch in range(epochs):
    ### train model ###
    model.train()
    epoch_loss, epoch_acc = 0, 0
    total_samples = 0
    # k = 0
    # generate a batch of training data, each training data contain T*D values
    for X_batch, y_batch in train_loader:
        # Forward pass
        optimizer.zero_grad()
        X_batch = X_batch.view(X_batch.size(0), 1, T, D)  # Add channel dimension
        outputs = model(X_batch.to(device))
        loss = criterion(outputs, y_batch.to(device))
        # Backward pass
        loss.backward()
        optimizer.step()
        # Accumulate metrics
        total_samples += y_batch.size(0)
        epoch_loss += loss.item()
        # epoch_acc += calculate_accuracy(outputs, y_batch)
        epoch_acc += calculate_accuracy(outputs, y_batch) * y_batch.size(0)  # Weighted accuracy
        # k += 1
    #
    # Average over all batches
    epoch_loss /= len(train_loader)
    # epoch_acc /= len(train_loader)
    epoch_acc /= total_samples  # Compute final train accuracy
    Train_Loss[epoch] = epoch_loss
    Train_Accuracy[epoch] = epoch_acc
    #

    print(f"Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

    ### test model ###
    model.eval()
    test_loss, test_acc = 0, 0

    with torch.no_grad():  # Disable gradient computation during evaluation
        for X_batch, y_batch in test_loader:
            # Forward pass
            X_batch = X_batch.view(X_batch.size(0), 1, T, D)  # Add channel dimension
            outputs = model(X_batch.to(device))
            loss = criterion(outputs, y_batch.to(device))
            # Accumulate metrics
            test_loss += loss.item()
            test_acc += calculate_accuracy(outputs, y_batch)

        # Average metrics over batches
        test_loss /= len(test_loader)
        test_acc /= len(test_loader)
        Test_Loss[epoch] = test_loss
        Test_Accuracy[epoch] = test_acc

    print(f"            Test  Loss: {test_loss:.4f}, Test  Accuracy: {test_acc:.4f}")
# Out:
# Epoch 1/40, Train Loss: 1.0934, Train Accuracy: 0.3695
#             Test  Loss: 1.1113, Test  Accuracy: 0.3557
# Epoch 2/40, Train Loss: 1.0868, Train Accuracy: 0.3852
#             Test  Loss: 1.0783, Test  Accuracy: 0.4031
# Epoch 3/40, Train Loss: 1.0334, Train Accuracy: 0.4614
#             Test  Loss: 1.0355, Test  Accuracy: 0.4726
# Epoch 4/40, Train Loss: 0.9755, Train Accuracy: 0.5141
#             Test  Loss: 1.0255, Test  Accuracy: 0.5050
# Epoch 5/40, Train Loss: 0.8825, Train Accuracy: 0.5829
#             Test  Loss: 0.8610, Test  Accuracy: 0.6012
# Epoch 6/40, Train Loss: 0.8391, Train Accuracy: 0.6065
#             Test  Loss: 0.8146, Test  Accuracy: 0.6296
# Epoch 7/40, Train Loss: 0.8181, Train Accuracy: 0.6193
#             Test  Loss: 0.8201, Test  Accuracy: 0.6217
# Epoch 8/40, Train Loss: 0.7985, Train Accuracy: 0.6321
#             Test  Loss: 0.8305, Test  Accuracy: 0.6278
# Epoch 9/40, Train Loss: 0.7842, Train Accuracy: 0.6406
#             Test  Loss: 0.7810, Test  Accuracy: 0.6500
# Epoch 10/40, Train Loss: 0.7751, Train Accuracy: 0.6459
#             Test  Loss: 0.7936, Test  Accuracy: 0.6413
# Epoch 11/40, Train Loss: 0.7751, Train Accuracy: 0.6466
#             Test  Loss: 0.8090, Test  Accuracy: 0.6422
# Epoch 12/40, Train Loss: 0.7791, Train Accuracy: 0.6447
#             Test  Loss: 0.7925, Test  Accuracy: 0.6410
# Epoch 13/40, Train Loss: 0.7627, Train Accuracy: 0.6548
#             Test  Loss: 0.7831, Test  Accuracy: 0.6501
# Epoch 14/40, Train Loss: 0.7655, Train Accuracy: 0.6529
#             Test  Loss: 0.7962, Test  Accuracy: 0.6385
# Epoch 15/40, Train Loss: 0.7533, Train Accuracy: 0.6596
#             Test  Loss: 0.7650, Test  Accuracy: 0.6588
# Epoch 16/40, Train Loss: 0.7534, Train Accuracy: 0.6601
#             Test  Loss: 0.7821, Test  Accuracy: 0.6504
# Epoch 17/40, Train Loss: 0.7532, Train Accuracy: 0.6595
#             Test  Loss: 0.7732, Test  Accuracy: 0.6524
# Epoch 18/40, Train Loss: 0.7450, Train Accuracy: 0.6646
#             Test  Loss: 0.7746, Test  Accuracy: 0.6537
# Epoch 19/40, Train Loss: 0.7456, Train Accuracy: 0.6641
#             Test  Loss: 0.7777, Test  Accuracy: 0.6518
# Epoch 20/40, Train Loss: 0.7392, Train Accuracy: 0.6679
#             Test  Loss: 0.7875, Test  Accuracy: 0.6472
# Epoch 21/40, Train Loss: 0.7379, Train Accuracy: 0.6689
#             Test  Loss: 0.7512, Test  Accuracy: 0.6654
# Epoch 22/40, Train Loss: 0.7423, Train Accuracy: 0.6654
#             Test  Loss: 0.7384, Test  Accuracy: 0.6767
# Epoch 23/40, Train Loss: 0.7369, Train Accuracy: 0.6692
#             Test  Loss: 0.7835, Test  Accuracy: 0.6485
# Epoch 24/40, Train Loss: 0.7403, Train Accuracy: 0.6672
#             Test  Loss: 0.7648, Test  Accuracy: 0.6586
# Epoch 25/40, Train Loss: 0.7293, Train Accuracy: 0.6735
#             Test  Loss: 0.7718, Test  Accuracy: 0.6544
# Epoch 26/40, Train Loss: 0.7370, Train Accuracy: 0.6691
#             Test  Loss: 0.7519, Test  Accuracy: 0.6682
# Epoch 27/40, Train Loss: 0.7288, Train Accuracy: 0.6737
#             Test  Loss: 0.7572, Test  Accuracy: 0.6656
# Epoch 28/40, Train Loss: 0.7242, Train Accuracy: 0.6763
#             Test  Loss: 0.7796, Test  Accuracy: 0.6485
# Epoch 29/40, Train Loss: 0.7241, Train Accuracy: 0.6765
#             Test  Loss: 0.7531, Test  Accuracy: 0.6664
# Epoch 30/40, Train Loss: 0.7254, Train Accuracy: 0.6757
#             Test  Loss: 0.7366, Test  Accuracy: 0.6755
# Epoch 31/40, Train Loss: 0.7271, Train Accuracy: 0.6740
#             Test  Loss: 0.7356, Test  Accuracy: 0.6774
# Epoch 32/40, Train Loss: 0.7195, Train Accuracy: 0.6787
#             Test  Loss: 0.8052, Test  Accuracy: 0.6435
# Epoch 33/40, Train Loss: 0.7214, Train Accuracy: 0.6782
#             Test  Loss: 0.7893, Test  Accuracy: 0.6448
# Epoch 34/40, Train Loss: 0.7174, Train Accuracy: 0.6799
#             Test  Loss: 0.7510, Test  Accuracy: 0.6707
# Epoch 35/40, Train Loss: 0.7154, Train Accuracy: 0.6811
#             Test  Loss: 0.7485, Test  Accuracy: 0.6693
# Epoch 36/40, Train Loss: 0.7140, Train Accuracy: 0.6823
#             Test  Loss: 0.7584, Test  Accuracy: 0.6598
# Epoch 37/40, Train Loss: 0.7149, Train Accuracy: 0.6811
#             Test  Loss: 1.0993, Test  Accuracy: 0.4590
# Epoch 38/40, Train Loss: 0.7146, Train Accuracy: 0.6813
#             Test  Loss: 0.7824, Test  Accuracy: 0.6386
# Epoch 39/40, Train Loss: 0.7109, Train Accuracy: 0.6837
#             Test  Loss: 0.7191, Test  Accuracy: 0.6859
# Epoch 40/40, Train Loss: 0.7094, Train Accuracy: 0.6844
#             Test  Loss: 0.7231, Test  Accuracy: 0.6826

# %%
Train_Loss=[1.0934,1.0868,1.0334,0.9755,0.8825,0.8391,0.8181,0.7985,0.7842,0.7751,0.7751,0.7791,0.7627,0.7655,0.7533,0.7534,0.7532,0.745,0.7456,0.7392,0.7379,0.7423,0.7369,0.7403,0.7293,0.737,0.7288,0.7242,0.7241,0.7254,0.7271,0.7195,0.7214,0.7174,0.7154,0.714,0.7149,0.7146,0.7109,0.7094]
Train_Accuracy=[0.3695,0.3852,0.4614,0.5141,0.5829,0.6065,0.6193,0.6321,0.6406,0.6459,0.6466,0.6447,0.6548,0.6529,0.6596,0.6601,0.6595,0.6646,0.6641,0.6679,0.6689,0.6654,0.6692,0.6672,0.6735,0.6691,0.6737,0.6763,0.6765,0.6757,0.674,0.6787,0.6782,0.6799,0.6811,0.6823,0.6811,0.6813,0.6837,0.6844]
Test_Loss=[1.1113,1.0783,1.0355,1.0255,0.861,0.8146,0.8201,0.8305,0.781,0.7936,0.809,0.7925,0.7831,0.7962,0.765,0.7821,0.7732,0.7746,0.7777,0.7875,0.7512,0.7384,0.7835,0.7648,0.7718,0.7519,0.7572,0.7796,0.7531,0.7366,0.7356,0.8052,0.7893,0.751,0.7485,0.7584,1.0993,0.7824,0.7191,0.7231]
Test_Accuracy=[0.3557,0.4031,0.4726,0.505,0.6012,0.6296,0.6217,0.6278,0.65,0.6413,0.6422,0.641,0.6501,0.6385,0.6588,0.6504,0.6524,0.6537,0.6518,0.6472,0.6654,0.6767,0.6485,0.6586,0.6544,0.6682,0.6656,0.6485,0.6664,0.6755,0.6774,0.6435,0.6448,0.6707,0.6693,0.6598,0.459,0.6386,0.6859,0.6826]
print(len(Train_Loss))
# Out:
# 40

# %%
sns.lineplot(x=range(1, epoch + 2), y=Train_Loss)
sns.lineplot(x=range(1, epoch + 2), y=Test_Loss)
plt.title('Model Cross Entropy Loss')
plt.ylabel('Cross Entropy Loss')
plt.xlabel('Epochs')
plt.legend(['Training', 'Testing'], loc='upper left')

# %%
sns.lineplot(x=range(1, epoch + 2), y=Train_Accuracy)
sns.lineplot(x=range(1, epoch + 2), y=Test_Accuracy)
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training', 'Testing'], loc='upper left')

# %%
# Ensure the model is in evaluation mode
model.eval()
print(device)
selected_indices = torch.randperm(X_test.shape[0], device=device)[:int(0.01 * X_test.shape[0])]
X_pred = X_test.to(device)[selected_indices]
y_true = y_test.to(device)[selected_indices]

X_pred = X_pred.to(device)
y_true = y_true.to(device)

# Reshape X_pred to match the expected input shape
X_pred = X_pred.view(X_pred.size(0), 1, T, D) # Reshape before passing to model

# Perform a forward pass
with torch.no_grad():  # Disable gradient computation
    y_pred_logits = model(X_pred)  # Get raw scores (logits)

# Get class predictions using argmax
y_pred = torch.argmax(y_pred_logits, dim=1).cpu().numpy()  # Convert to NumPy array if needed

# Print predictions
print(y_pred)
# Out:
# cuda
# [2 0 0 ... 1 2 0]

# %%
from sklearn.metrics import confusion_matrix

y_true_cpu = y_true.cpu().numpy()
#y_pred_cpu = y_pred.cpu().numpy()
cm = confusion_matrix(y_pred=y_pred, y_true=y_true_cpu)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
ax=sns.heatmap(cm, annot=True, xticklabels=[0,1,2], yticklabels=[0,1,2], cmap='Blues')
ax.set_ylim(3.0, 0)
plt.show()

# %%
print(classification_report(y_true_cpu, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.50      0.60       713
#            1       0.45      0.94      0.60       445
#            2       0.78      0.43      0.56       603
#
#     accuracy                           0.59      1761
#    macro avg       0.66      0.63      0.59      1761
# weighted avg       0.68      0.59      0.59      1761
